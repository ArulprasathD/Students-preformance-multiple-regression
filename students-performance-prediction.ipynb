# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data

# %%
students  =pd.read_csv("StudentPerformanceFactors.csv")

# %%
students.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
students.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
students.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
students.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
students['Teacher_Quality'] = students['Teacher_Quality'].fillna(
    students['Teacher_Quality'].mode()[0]
)

# %%
students['Parental_Education_Level'] = students['Parental_Education_Level'].fillna(
    students['Parental_Education_Level'].mode()[0]
)

# %%
students['Distance_from_Home'] = students['Distance_from_Home'].fillna(
    students['Distance_from_Home'].mode()[0]
)

# %%
students.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
students.duplicated().sum()
# Out:
# np.int64(0)

# %%
#EDA

# %%
sns.pairplot(
    students,
    kind = "scatter",
    plot_kws={'alpha' : 0.3},
    diag_kws = {'alpha':0.4,'bins':40}
)

# %%
sns.scatterplot(x="Attendance",y = "Exam_Score",hue = "Hours_Studied",data=students )
plt.show()

# %%
students.corr(numeric_only=True)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
sns.heatmap(
    students.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)
plt.show()

# %% [markdown]
# Attendance and Exam Score show a positive correlation. Students with higher attendance tend to achieve better exam scores.
# Hours Studied also appears to have a positive impact on performance

# %%
#train test split

# %%
students.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6607 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
X = students[
    [
        "Hours_Studied",
        "Attendance",
        "Sleep_Hours",
        "Previous_Scores",
        "Tutoring_Sessions",
        "Physical_Activity",
    ]
]

# %%
y = students["Exam_Score"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,y,
          test_size = 0.3,
          random_state = 42 
)

# %%
lm.coef_
# Out:
# array([ 0.2882375 ,  0.19946534, -0.03428051,  0.04911817,  0.51416185,
#         0.13377177])

# %%
lm.score(X_train,y_train)
# Out:
# 0.5812642724015835

# %%
cef = pd.DataFrame(lm.coef_,X.columns,columns = ["coefficent"])
cef
# Out:
#                    coefficent
# Hours_Studied        0.288238
# Attendance           0.199465
# Sleep_Hours         -0.034281
# Previous_Scores      0.049118
# Tutoring_Sessions    0.514162
# Physical_Activity    0.133772

# %%
from sklearn.linear_model import LinearRegression

# %%
#create model

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train);

# %%
#prediction

# %%
predicition = lm.predict(X_test)

# %%
sns.scatterplot(x=y_test,y=predicition)

plt.ylabel("prediction")
plt.title("EXAM SCORE VS PREDICTION")
plt.show()

# %%
#evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print(f"MEAN ABSOLUTE ERROR : {mean_absolute_error(y_test,predicition):.2f}")
print(f"MEAN SQUARED ERROR  : {mean_squared_error(y_test,predicition):.2f}")
print(f"R2 SCORE            : {r2_score(y_test,predicition):.2f}")
print(f"INTERCEPT           : {lm.intercept_:.2f}")
# Out:
# MEAN ABSOLUTE ERROR : 1.27
# MEAN SQUARED ERROR  : 4.90
# R2 SCORE            : 0.64
# INTERCEPT           : 40.91
